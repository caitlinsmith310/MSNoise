# %%
from obspy import read
import matplotlib.pyplot as plt

# %matplotlib notebook

st1=read("/home/csmi310/msnoise/STACKS/01/001_DAYS/ZZ/NZ_WIAZ_NZ_WTAZ/2016-01-08.MSEED")
st1.plot
    
st3=read("/home/csmi310/msnoise/STACKS/01/REF/ZZ/NZ_WIAZ_NZ_WTAZ.MSEED")
#st2=read("/home/csmi310/msnoise/STACKS/01/001_DAYS/ZZ/NZ_EPAZ_NZ_HBAZ/2016-01-01.MSEED")
st1.plot()
st3.plot()
#st2.plot()
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
